# %% [markdown]
# # Data Exploration - EGFR GNN
#
# This notebook demonstrates basic loading and inspection of processed PyG graphs.

# %%
# Imports
import torch
from torch_geometric.data import DataLoader
import matplotlib.pyplot as plt
from pathlib import Path

# Load processed graphs
graphs_path = Path('data/processed/graph_data.pt')
if graphs_path.exists():
    graphs = torch.load(str(graphs_path))
    print(f'Loaded {len(graphs)} graphs')
    sample = graphs[0]
    print('Node features shape:', sample.x.shape)
else:
    print('No processed graphs found. Run src/data_prep.py first.')
