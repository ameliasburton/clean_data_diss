# %% [markdown]
# # train.py converted
# GNN training loop for EGFR regressor converted to notebook.

# %%
"""
Training loop for the EGFR GNN regressor.
"""
import torch
from torch_geometric.data import DataLoader
import torch.optim as optim
import torch.nn as nn


# Placeholder classes/functions to avoid cross-notebook imports in notebook mode
class EGFR_GNN_Regressor(nn.Module):
    """Placeholder GNN model"""
    def __init__(self):
        super().__init__()
        self.linear = nn.Linear(1, 1)
    
    def forward(self, x, edge_index, batch, edge_attr=None, global_features=None):
        return torch.zeros(batch.max().item() + 1)


def load_dataset(path):
    """Placeholder dataset loader"""
    return []


def train_epoch(model, loader, optimizer, device='cpu'):
    model.train()
    losses = []
    for batch in loader:
        batch = batch.to(device)
        optimizer.zero_grad()
        out = model(batch.x, batch.edge_index, batch.batch, edge_attr=batch.edge_attr, global_features=batch.global_features)
        loss = nn.MSELoss()(out, batch.y)
        loss.backward()
        optimizer.step()
        losses.append(loss.item())
    return sum(losses) / len(losses) if losses else 0.0


# In notebook environment, skip actual training
print("train utility functions defined successfully")
# Out:
# train utility functions defined successfully
